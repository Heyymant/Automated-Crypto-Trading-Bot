# %%
import pandas as pd
from binance.client import Client
from binance_key import secret_key , api_key

# %%
client = Client(api_key , secret_key)

# %%
# list of coins we wanna gather
coins = ['BTC' ,'ETH' ,'LTC']

# %%
merge = False
for coin in coins :
    start_date = "May 1, 2022"
    klines = client.get_historical_klines(symbol = f'{coin}USDT', interval = client.KLINE_INTERVAL_1MINUTE, start_str = start_date)

    # initializing the columns 
    cols = [
        'OpenTime',
        f'{coin}-USD_Open',
        f'{coin}-USD_High',
        f'{coin}-USD_Low',
        f'{coin}-USD_Close',
        f'{coin}-USD_Volume',
        'CloseTime',
        f'{coin}-QuoteAssetVolume',
        f'{coin}-NumberOfTrades',
        f'{coin}-TBBASV',
        f'{coin}-TBQAV',
        f'{coin}-ignore',

    ]

    #  setting the columns to cols 
    # klines.columns = cols 
    coin_df = pd.DataFrame(klines ,columns  = cols)
    

    if merge == True:
        all_coins_df = pd.merge(coin_df ,all_coins_df, how ='inner', on = ['OpenTime' , 'CloseTime'])
    else :
        all_coins_df = coin_df
        merge = True

# %%
#  klines
# 
# returns 
# [
#     [
#         1499040000000,      # Open time
#         "0.01634790",       # Open
#         "0.80000000",       # High
#         "0.01575800",       # Low
#         "0.01577100",       # Close
#         "148976.11427815",  # Volume
#         1499644799999,      # Close time
#         "2434.19055334",    # Quote asset volume
#         308,                # Number of trades
#         "1756.87402397",    # Taker buy base asset volume
#         "28.46694368",      # Taker buy quote asset volume
#         "17928899.62484339" # Can be ignored
#     ]
# ]

# %%
all_coins_df
# Out:
#             OpenTime LTC-USD_Open LTC-USD_High  LTC-USD_Low LTC-USD_Close  \
# 0      1651363200000  95.90000000  95.90000000  95.70000000   95.90000000
# 1      1651363260000  95.80000000  95.90000000  95.70000000   95.80000000
# 2      1651363320000  95.80000000  96.00000000  95.80000000   95.90000000
# 3      1651363380000  96.00000000  96.10000000  95.80000000   96.10000000
# 4      1651363440000  96.00000000  96.10000000  96.00000000   96.10000000
# ...              ...          ...          ...          ...           ...
# 30361  1653184860000  70.10000000  70.20000000  70.10000000   70.20000000
# 30362  1653184920000  70.10000000  70.20000000  70.10000000   70.20000000
# 30363  1653184980000  70.10000000  70.20000000  70.10000000   70.20000000
# 30364  1653185040000  70.20000000  70.20000000  70.00000000   70.00000000
# 30365  1653185100000  70.10000000  70.10000000  70.00000000   70.00000000
#
#       LTC-USD_Volume      CloseTime LTC-QuoteAssetVolume  LTC-NumberOfTrades  \
# 0       824.17500000  1651363259999       78922.20750000                  87
# 1       172.27900000  1651363319999       16498.94580000                  34
# 2       320.81500000  1651363379999       30763.70210000                  61
# 3       726.73500000  1651363439999       69705.25150000                 115
# 4       669.64900000  1651363499999       64288.67940000                  65
# ...              ...            ...                  ...                 ...
# 30361   151.72500000  1653184919999       10651.03380000                   9
# 30362    38.17100000  1653184979999        2678.87980000                   8
# 30363    27.33100000  1653185039999        1918.35000000                   6
# 30364   354.68200000  1653185099999       24860.85730000                  42
# 30365    74.56800000  1653185159999        5223.40800000                  15
#
#          LTC-TBBASV  ...    BTC-USD_Open    BTC-USD_High     BTC-USD_Low  \
# 0      133.75700000  ...  37630.80000000  37665.29000000  37612.43000000
# 1       74.52200000  ...  37645.92000000  37645.93000000  37622.48000000
# 2      172.95000000  ...  37642.28000000  37684.71000000  37642.28000000
# 3      417.83600000  ...  37672.11000000  37738.97000000  37661.89000000
# 4      471.39400000  ...  37737.09000000  37737.09000000  37700.74000000
# ...             ...  ...             ...             ...             ...
# 30361  151.11300000  ...  29495.75000000  29498.55000000  29495.74000000
# 30362   30.92700000  ...  29498.54000000  29498.55000000  29495.21000000
# 30363   24.46900000  ...  29495.21000000  29495.22000000  29489.81000000
# 30364   80.42200000  ...  29491.06000000  29491.07000000  29480.54000000
# 30365   36.48000000  ...  29487.51000000  29487.52000000  29485.36000000
#
#         BTC-USD_Close BTC-USD_Volume BTC-QuoteAssetVolume BTC-NumberOfTrades  \
# 0      37645.92000000    85.80484000     3229135.93967060               1271
# 1      37642.29000000    28.27385000     1064073.13040180                677
# 2      37672.10000000    70.97044000     2673472.22944150                904
# 3      37737.08000000    81.17584000     3059012.63948520               1168
# 4      37717.79000000    38.43930000     1449841.49572520               1022
# ...               ...            ...                  ...                ...
# 30361  29498.54000000     1.66207000       49025.94396720                220
# 30362  29495.21000000     5.09064000      150162.40558130                278
# 30363  29491.06000000     5.06722000      149438.86777600                307
# 30364  29487.52000000    14.82486000      437116.12105360                491
# 30365  29485.36000000     1.01145000       29824.93218280                 76
#
#         BTC-TBBASV         BTC-TBQAV BTC-ignore
# 0      37.66777000  1417547.36651720          0
# 1      18.31689000   689329.63879220          0
# 2      29.13056000  1097093.92147740          0
# 3      54.89804000  2068797.26991660          0
# 4      15.17617000   572376.82784910          0
# ...            ...               ...        ...
# 30361   1.01356000    29896.57317580          0
# 30362   1.31591000    38816.88847110          0
# 30363   1.22972000    36267.32906270          0
# 30364   5.36472000   158167.74712520          0
# 30365   0.14819000     4369.74201950          0
#
# [30366 rows x 32 columns]

# %%
from datetime import datetime,  timezone

# %%
# all_coins_df.OpenTime[0]  # to remove miliseconds as it timestamp doesnt includse it


# all_coins_df.OpenTime = [datetime.fromtimestamp(ts // 1000) for ts in all_coins_df.OpenTime]
# all_coins_df.CloseTime = [datetime.fromtimestamp(ts) for ts in all_coins_df.CloseTime ]

# for ts in all_coins_df.OpenTime:
#     datetime.fromtimestamp(ts//1000)

# %%
for col in all_coins_df.columns :
    if not 'Time' in col :
        all_coins_df[col] = all_coins_df[col].astype(float)

# %%
# all_coins_df

# %%
pip install plotly

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\hemant\appdata\local\programs\python\python310\lib\site-packages (5.8.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\hemant\appdata\local\programs\python\python310\lib\site-packages (from plotly) (8.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
fig = go.Figure(data=[go.Candlestick(x=all_coins_df['OpenTime'],
                open = all_coins_df['BTC-USD_Open'],
                high = all_coins_df['BTC-USD_High'],
                low = all_coins_df['BTC-USD_Low'],
                close = all_coins_df['BTC-USD_Close'])])

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Hemant\Documents\CODING\Trading bot\crypto_bot\data_gather.ipynb Cell 14' in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Hemant/Documents/CODING/Trading%20bot/crypto_bot/data_gather.ipynb#ch0000016?line=0'>1</a> fig = go.Figure(data=[go.Candlestick(x=all_coins_df['OpenTime'],
#       <a href='vscode-notebook-cell:/c%3A/Users/Hemant/Documents/CODING/Trading%20bot/crypto_bot/data_gather.ipynb#ch0000016?line=1'>2</a>                 open = all_coins_df['BTC-USD_Open'],
#       <a href='vscode-notebook-cell:/c%3A/Users/Hemant/Documents/CODING/Trading%20bot/crypto_bot/data_gather.ipynb#ch0000016?line=2'>3</a>                 high = all_coins_df['BTC-USD_High'],
#       <a href='vscode-notebook-cell:/c%3A/Users/Hemant/Documents/CODING/Trading%20bot/crypto_bot/data_gather.ipynb#ch0000016?line=3'>4</a>                 low = all_coins_df['BTC-USD_Low'],
#       <a href='vscode-notebook-cell:/c%3A/Users/Hemant/Documents/CODING/Trading%20bot/crypto_bot/data_gather.ipynb#ch0000016?line=4'>5</a>                 close = all_coins_df['BTC-USD_Close'])])
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Hemant/Documents/CODING/Trading%20bot/crypto_bot/data_gather.ipynb#ch0000016?line=6'>7</a> fig.show()
#
# File c:\Users\Hemant\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:3398, in BaseFigure.show(self, *args, **kwargs)
#    <a href='file:///c%3A/Users/Hemant/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/basedatatypes.py?line=3364'>3365</a> """
#    <a href='file:///c%3A/Users/Hemant/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/basedatatypes.py?line=3365'>3366</a> Show a figure using either the default renderer(s) or the renderer(s)
#    <a href='file:///c%3A/Users/Hemant/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/basedatatypes.py?line=3366'>3367</a> specified by the renderer argument
#    (...)
#    <a href='file:///c%3A/Users/Hemant/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/basedatatypes.py?line=3393'>3394</a> None
#    <a href='file:///c%3A/Users/Hemant/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/basedatatypes.py?line=3394'>3395</a> """
#    <a href='file:///c%3A/Users/Hemant/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/basedatatypes.py?line=3395'>3396</a> import plotly.io as pio
# -> <a href='file:///c%3A/Users/Hemant/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/basedatatypes.py?line=3397'>3398</a> return pio.show(self, *args, **kwargs)
#
# File c:\Users\Hemant\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     <a href='file:///c%3A/Users/Hemant/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/io/_renderers.py?line=390'>391</a>         raise ValueError(
#     <a href='file:///c%3A/Users/Hemant/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/io/_renderers.py?line=391'>392</a>             "Mime type rendering requires ipython but it is not installed"
#     <a href='file:///c%3A/Users/Hemant/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/io/_renderers.py?line=392'>393</a>         )
#     <a href='file:///c%3A/Users/Hemant/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/io/_renderers.py?line=394'>395</a>     if not nbformat or LooseVersion(nbformat.__version__) < LooseVersion("4.2.0"):
# --> <a href='file:///c%3A/Users/Hemant/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/io/_renderers.py?line=395'>396</a>         raise ValueError(
#     <a href='file:///c%3A/Users/Hemant/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/io/_renderers.py?line=396'>397</a>             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     <a href='file:///c%3A/Users/Hemant/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/io/_renderers.py?line=397'>398</a>         )
#     <a href='file:///c%3A/Users/Hemant/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/io/_renderers.py?line=399'>400</a>     ipython_display.display(bundle, raw=True)
#     <a href='file:///c%3A/Users/Hemant/AppData/Local/Programs/Python/Python310/lib/site-packages/plotly/io/_renderers.py?line=401'>402</a> # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %%
# Out:
# Collecting nbformat
#   Downloading nbformat-5.4.0-py3-none-any.whl (73 kB)
#      -------------------------------------- 73.3/73.3 kB 808.6 kB/s eta 0:00:00
# Collecting fastjsonschema
#   Downloading fastjsonschema-2.15.3-py3-none-any.whl (22 kB)
# Requirement already satisfied: traitlets>=5.1 in c:\users\hemant\appdata\local\programs\python\python310\lib\site-packages (from nbformat) (5.2.1.post0)
# Collecting jsonschema>=2.6
#   Downloading jsonschema-4.5.1-py3-none-any.whl (72 kB)
#      ---------------------------------------- 72.9/72.9 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: jupyter-core in c:\users\hemant\appdata\local\programs\python\python310\lib\site-packages (from nbformat) (4.10.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\hemant\appdata\roaming\python\python310\site-packages (from jsonschema>=2.6->nbformat) (21.4.0)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.18.1-cp310-cp310-win_amd64.whl (61 kB)
#      ---------------------------------------- 61.6/61.6 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: pywin32>=1.0 in c:\users\hemant\appdata\local\programs\python\python310\lib\site-packages (from jupyter-core->nbformat) (304)
# Installing collected packages: fastjsonschema, pyrsistent, jsonschema, nbformat
# Successfully installed fastjsonschema-2.15.3 jsonschema-4.5.1 nbformat-5.4.0 pyrsistent-0.18.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script jsonschema.exe is installed in 'c:\Users\Hemant\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-trust.exe is installed in 'c:\Users\Hemant\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
